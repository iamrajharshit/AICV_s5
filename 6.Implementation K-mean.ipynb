# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
x=np.random.rand(100,2) #gentrating random feature
#numbers of cluster 
k=4
#init the KMeans model
kmeans=KMeans(n_clusters=k)

#fit model
kmeans.fit(x)

#get cluster centers and labels
cluster_centers = kmeans.cluster_centers_
labels = kmeans.labels_

#plot the data pointsand cluster center
plt.scatter(x[:,0],x[:,1],c=labels)
plt.scatter(cluster_centers[:,0],cluster_centers[:,1],marker='x',s=200,color='red')
plt.title(f"K-Means Clustering (k=(k))")
plt.show()
# Out:
# /home/student/.conda/envs/build1/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
